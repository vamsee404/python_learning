# %%
import csv

with open("sales.csv", "r", newline="") as f:
    reader = csv.reader(f, delimiter=',')
    for row in reader:
        print(row)

# %%
import csv
with open("first_csv.csv", "r", newline="") as f:
    content = f.read()
    print("File content:")
    print(content)

# %%
import os
print(os.getcwd())

# %%
li=['Hello', 'this', 'is', 'line', 'one']
cnt=0
cnt=len(li)
print(cnt)
x=[for word in li]
print(x)
# Out:
# 5
# [['Hello'], ['this'], ['is'], ['line'], ['one']]
